# %%
# ✅ 1. 기본 라이브러리 불러오기
import pandas as pd              # pandas(판다스): 데이터 분석용 라이브러리 (엑셀처럼 표 데이터 다룸)
import matplotlib.pyplot as plt   # matplotlib: 시각화(그래프 그리기)
import seaborn as sns             # seaborn: matplotlib보다 예쁜 그래프 스타일 제공
import numpy as np  # 수치 계산 및 배열 연산을 위한 NumPy 라이브러리            
# ✅ 한글 폰트 깨짐 방지 (그래프 제목이 ??? 로 깨지는 걸 막기 위함)
plt.rc('font', family='Malgun Gothic')   # '맑은 고딕' 폰트를 기본으로 설정
plt.rcParams['axes.unicode_minus'] = False  # 그래프에서 마이너스(-) 기호가 깨지지 않게 설정

# %%
import pandas as pd
import numpy as np
import
